# %%
import requests
from bs4 import BeautifulSoup
from requests_html import HTMLSession,AsyncHTMLSession

# %%
asession = AsyncHTMLSession()
r = asession.get('http://python-requests.org/')

await r.html.arender()

r.html.search('Python 2 will retire in only {months} months!')['months']
'<time>25</time>'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-12e9b64b498d> in async-def-wrapper()
#       5
#       6 r.html.search('Python 2 will retire in only {months} months!')['months']
# ----> 7 '<time>25</time>'
#
# AttributeError: '_asyncio.Future' object has no attribute 'html'

# %%
session = HTMLSession()
r = session.get('http://python-requests.org/')

r.html.render()

r.html.search('Python 2 will retire in only {months} months!')['months']
'<time>25</time>'
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-9-8d9d67a462d9> in <module>
#       2 r = session.get('http://python-requests.org/')
#       3
# ----> 4 r.html.render()
#       5
#       6 r.html.search('Python 2 will retire in only {months} months!')['months']
#
# ~/anaconda3/envs/sql/lib/python3.7/site-packages/requests_html.py in render(self, retries, script, wait, scrolldown, sleep, reload, timeout, keep_page)
#     584         """
#     585
# --> 586         self.browser = self.session.browser  # Automatically create a event loop and browser
#     587         content = None
#     588
#
# ~/anaconda3/envs/sql/lib/python3.7/site-packages/requests_html.py in browser(self)
#     727             self.loop = asyncio.get_event_loop()
#     728             if self.loop.is_running():
# --> 729                 raise RuntimeError("Cannot use HTMLSession within an existing event loop. Use AsyncHTMLSession instead.")
#     730             self._browser = self.loop.run_until_complete(super().browser)
#     731         return self._browser
#
# RuntimeError: Cannot use HTMLSession within an existing event loop. Use AsyncHTMLSession instead.

# %%
url = 'https://www.metmuseum.org/art/collection/search#!?material=Vases'
url = 'https://www.metmuseum.org/art/collection/search/484904?searchField=All&amp;sortBy=DateDesc&amp;what=Vases&amp;ft=*&amp;offset=0&amp;rpp=80&amp;pos=33'
url = 'https://www.metmuseum.org/art/collection/search/254861?searchField=All&amp;what=Vases&amp;showOnly=openAccess&amp;ft='
r = requests.get(url)
print(r)
# Out:
# <Response [200]>

# %%
url = 'https://www.metmuseum.org/art/collection/search/76441?searchField=All&amp;sortBy=DateDesc&amp;what=Vases&amp;ft=*&amp;offset=0&amp;rpp=80&amp;pos=43'
url = 'https://www.metmuseum.org/art/collection/search/254861?searchField=All&amp;what=Vases&amp;showOnly=openAccess&amp;ft='
s = requests.Session()
r = s.get(url).text
print(r)
# Out:
# <html>
# <head>
# <META NAME="robots" CONTENT="noindex,nofollow">
# <script src="/_Incapsula_Resource?SWJIYLWA=5074a744e2e3d891814e9a2dace20bd4,719d34d31c8e3a6e6fffd425f7e032f3">
# </script>
# <body>
# </body></html>

# %%
session = HTMLSession()

r = session.get(url)
#<a href="https://images.metmuseum.org/CRDImages/gr/original/DP104352.jpg" class="gtm__download__image" title="Download" download>
print(r.content)
# Out:
# b'\r\n\r\n<!DOCTYPE html>\r\n\r\n\t<html lang="en">\r\n\r\n<head>\r\n\r\n    \r\n    <!-- Destroy all Monsters -->\r\n<title>Attributed to the Eucharides Painter | Terracotta Panathenaic prize amphora (jar) | Greek, Attic | Archaic | The Met</title>\r\n<meta charset="UTF-8">\r\n<meta name="viewport" content="width=device-width, initial-scale=1.0">\r\n\r\n    <meta name="title" content="Attributed to the Eucharides Painter | Terracotta Panathenaic prize amphora (jar) | Greek, Attic | Archaic | The Met" />\r\n    <meta name="keywords" content="Eucharides Painter, Clay, Terracotta, Vessels, Vases, Amphorae, Europe, Greece" />\r\n<link rel="canonical" href="https://www.metmuseum.org/art/collection/search/254861" />\r\n\r\n    <meta property="og:image" content="https://collectionapi.metmuseum.org/api/collection/v1/iiif/254861/530627/main-image" />\r\n    <meta name="twitter:image" content="https://collectionapi.metmuseum.org/api/collection/v1/iiif/254861/530627/main-image" />\r\n\r\n    <meta property="og:url" content="https://www.metmuseum.org/art/collection/search/254861" />\r\n\r\n    <meta property="og:title" content="Attributed to the Eucharides Painter | Terracotta Panathenaic prize amphora (jar) | Greek, Attic | Archaic | The Met" />\r\n    <meta name="twitter:title" content="Attributed to the Eucharides Painter | Terracotta Panathenaic prize amphora (jar) | Greek, Attic | Archaic | The Met" />\r\n\r\n    <meta property="og:type" content="website" />\r\n\r\n    <meta property="og:site_name" content="The Metropolitan Museum of Art" />\r\n\r\n\r\n    <meta name="twitter:card" content="summary_large_image" />\r\n\r\n    <meta name="twitter:site" value="@metmuseum" />\r\n\r\n\r\n\r\n    <link rel="preconnect" href="//logx.optimizely.com">\r\n    <script src="https://cdn.optimizely.com/js/8306101470.js" defer></script>\r\n\r\n    \r\n    <!-- preload fonts -->\r\n    <link rel="preload" href="https://www.metmuseum.org/assets/fonts/TheMetSans/TheMetSans-Bold.woff2?022020" as="font" type="font/woff" crossorigin>\r\n    <link rel="preload" href="https://www.metmuseum.org/assets/fonts/TheMetSans/TheMetSans-Regular.woff2?022020" as="font" type="font/woff" crossorigin>\r\n    <link rel="preload" href="https://www.metmuseum.org/assets/fonts/TheMetSans/TheMetSans-Semibold.woff2?022020" as="font" type="font/woff" crossorigin>\r\n\r\n    <link href="/Rodan/dist/hashed/turtles-gazing-at-clouds-001053e57b.css" rel="stylesheet" />\r\n<link href="/Rodan/dist/css/turtles-printing-on-clouds.css" rel="stylesheet" type="text/css" media="print" />\r\n\r\n\r\n    <link rel="shortcut icon" href="/content/img/presentation/icons/favicons/favicon.ico?v=3">\r\n    <link rel="apple-touch-icon" sizes="57x57" href="/content/img/presentation/icons/favicons/apple-icon-57x57.png?v=3">\r\n    <link rel="apple-touch-icon" sizes="60x60" href="/content/img/presentation/icons/favicons/apple-icon-60x60.png?v=3">\r\n    <link rel="apple-touch-icon" sizes="72x72" href="/content/img/presentation/icons/favicons/apple-icon-72x72.png?v=3">\r\n    <link rel="apple-touch-icon" sizes="76x76" href="/content/img/presentation/icons/favicons/apple-icon-76x76.png?v=3">\r\n    <link rel="apple-touch-icon" sizes="114x114" href="/content/img/presentation/icons/favicons/apple-icon-114x114.png?v=3">\r\n    <link rel="apple-touch-icon" sizes="120x120" href="/content/img/presentation/icons/favicons/apple-icon-120x120.png?v=3">\r\n    <link rel="apple-touch-icon" sizes="144x144" href="/content/img/presentation/icons/favicons/apple-icon-144x144.png?v=3">\r\n    <link rel="apple-touch-icon" sizes="152x152" href="/content/img/presentation/icons/favicons/apple-icon-152x152.png?v=3">\r\n    <link rel="apple-touch-icon" sizes="180x180" href="/content/img/presentation/icons/favicons/apple-icon-180x180.png?v=3">\r\n    <link rel="icon" type="image/png" sizes="192x192" href="/content/img/presentation/icons/favicons/android-icon-192x192.png?v=3">\r\n    <link rel="icon" type="image/png" sizes="32x ...

# %%
#import nest_asyncio
#nest_asyncio.apply()

session = HTMLSession()
url = 'https://www.metmuseum.org/art/collection/search#!?showOnly=withImage&offset=0&pageSize=0&perPage=20&sortBy=Date&sortOrder=asc&searchField=All&material=Vases'
r = session.get(url)
r.html.render()
print(h)
#soup = BeautifulSoup(session.get(url).content)
#print(soup)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-c6dbcd2ee619> in <module>
#       5 url = 'https://www.metmuseum.org/art/collection/search#!?showOnly=withImage&offset=0&pageSize=0&perPage=20&sortBy=Date&sortOrder=asc&searchField=All&material=Vases'
#       6 r = session.get(url)
# ----> 7 r.html.render()
#       8 print(h)
#       9 #soup = BeautifulSoup(session.get(url).content)
#
# ~/anaconda3/envs/sql/lib/python3.7/site-packages/requests_html.py in render(self, retries, script, wait, scrolldown, sleep, reload, timeout, keep_page)
#     584         """
#     585
# --> 586         self.browser = self.session.browser  # Automatically create a event loop and browser
#     587         content = None
#     588
#
# ~/anaconda3/envs/sql/lib/python3.7/site-packages/requests_html.py in browser(self)
#     727             self.loop = asyncio.get_event_loop()
#     728             if self.loop.is_running():
# --> 729                 raise RuntimeError("Cannot use HTMLSession within an existing event loop. Use AsyncHTMLSession instead.")
#     730             self._browser = self.loop.run_until_complete(super().browser)
#     731         return self._browser
#
# RuntimeError: Cannot use HTMLSession within an existing event loop. Use AsyncHTMLSession instead.

# %%
asession = AsyncHTMLSession()
url = 'https://www.metmuseum.org/art/collection/search#!?showOnly=withImage&offset=0&pageSize=0&perPage=20&sortBy=Date&sortOrder=asc&searchField=All&material=Vases'
#r = session.get(url)
r = asession.get(url)
print(r)
# Out:
# <Future pending cb=[_chain_future.<locals>._call_check_cancel() at /Users/officialbiznas/anaconda3/envs/sql/lib/python3.7/asyncio/futures.py:351]>

# %%
await r.arender()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-486106aa814e> in async-def-wrapper()
#
# AttributeError: '_asyncio.Future' object has no attribute 'arender'

# %%
def get_html(urlX):
    asession = AsyncHTMLSession()
    r = asession.get(url)
